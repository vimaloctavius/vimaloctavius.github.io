# %% [markdown]
# ##Abstract
# Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset.

# %% [markdown]
# Dataset from https://archive-beta.ics.uci.edu/ml/datasets/adult
#
# Adult. (1996). UCI Machine Learning Repository.

# %% [markdown]
# We could aim to explore **Classification algorithms**: Xgboost, Support Vector Machines, Random Forest, Neural Network, Logistic Regression, K Nearest Neighbors

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/adult.data", names = ['age','workclass','fnlwgt','education','education-num', 'marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','<=50K'],header=None,index_col=False)

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  ... hours-per-week  native-country   <=50K
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        '<=50K'],
#       dtype='object')

# %%
model_features = df.columns.drop('<=50K')
model_target = '<=50K'
print('Model Features: ', model_features)
print('Model Target: ', model_target)
# Out:
# Model Features:  Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'],
#       dtype='object')
# Model Target:  <=50K

# %% [markdown]
# Exploring Numerical and Categorical Features

# %%
from pandas.core.arrays import categorical
import numpy as np
numerical_features_all = df[model_features].select_dtypes(include=np.number).columns
print('Numerical Columns: ', numerical_features_all)
categorical_features_all = df[model_features].select_dtypes(include='object').columns
print('Categorical Columns: ', categorical_features_all)
# Out:
# Numerical Columns:  Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')
# Categorical Columns:  Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country'],
#       dtype='object')

# %% [markdown]
# Plotting the Basics

# %%
df[model_target].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: <=50K, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df[model_target].value_counts().plot.bar(color='cornflowerblue')
plt.show()

# %%
# An efficient way to summarize the data in our Categorical Features
for c in categorical_features_all:
  print(df[c].value_counts())
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64
# ...

# %% [markdown]
# It would'nt be very useful to visualize Unique values, if any.  Let's see what a bar plot of our Categorical Features look like

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for c in categorical_features_all:
  print(c)
  df[c].value_counts().plot.bar()
  plt.show()
# Out:
# workclass
# education
# marital-status
# occupation
# relationship
# race
# sex
# native-country

# %% [markdown]
# To visualize distribution of our Numerical data we could use Histograms, where data is divided into 'buckets' or 'bins'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for n in numerical_features_all:
  print(n)
  df[n].value_counts().plot.hist(bins=5)
  plt.grid(True)
  plt.show()
# Out:
# age
# fnlwgt
# education-num
# capital-gain
# capital-loss
# hours-per-week

# %% [markdown]
# To be continued..
